# %%
import oakvar as ov

# %% [markdown]
# You will need to `pip install connectorx == 0.3.2`

# %%
df = ov.get_df_from_db('exampleinput.sqlite').to_pandas()

# %%
df.iloc[:,:10]
# Out:
#      base__uid base__chrom  base__pos  base__pos_end base__ref_base  \
# 0            1       chr10  121593817      121593817              T
# 1            2       chr10    2987654        2987654              T
# 2            3       chr10   43077259       43077259              A
# 3            4       chr10    8055656        8055656              A
# 4            5       chr10   87864470       87864470              A
# ..         ...         ...        ...            ...            ...
# 368        369        chrX   64193286       64193286              T
# 369        370        chrX   67545147       67545147              A
# 370        371        chrX   71120077       71120077              A
# 371        372        chrX   77786001       77786001              T
# 372        373        chrY   13479665       13479665              T
#
#     base__alt_base base__tags base__coding base__hugo    base__transcript
# 0                A       None            Y      FGFR2  ENST00000358487.10
# ...

# %%
df.iloc[:,10:]
# Out:
#     base__so base__cchange base__achange  base__exonno  \
# 0        MLO        c.1A>T       p.Met1?           2.0
# 1       None          None          None           NaN
# 2        MLO        c.1A>T       p.Met1?           1.0
# 3        MLO        c.1A>T       p.Met1?           2.0
# 4        MLO        c.1A>T       p.Met1?           1.0
# ..       ...           ...           ...           ...
# 368      MLO        c.1A>T       p.Met1?           2.0
# 369      MLO        c.1A>T       p.Met1?           1.0
# 370      MIS      c.460A>T   p.Met154Leu           4.0
# 371      MLO        c.1A>T       p.Met1?           1.0
# 372      MLO        c.1A>T       p.Met1?           1.0
#
#                                     base__all_mappings  base__refseq  \
# 0    {"FGFR2": [["P21802", "p.Met1?", "MIS,MLO", "E...     NM_000141
# 1                                                   {}          None
# 2    {"RET": [["P07949", "p.Met1?", "MIS,MLO", "ENS...     NM_020975
# ...
